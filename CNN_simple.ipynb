# %% [markdown]
# <a href="https://colab.research.google.com/github/yunhyeongil/docs-l10n/blob/master/CNN_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Review : convolutional neural networks (CNNs)

# %% [markdown]
# ### CNN layers = Feature Extractor for Images
# - the early layers (those right after the input layer) extract **low-level features** from raw data, and
# - the later layers (often **fully connected layers** like in a multilayer perceptron (MLP)) use these features to predict a continuous target value or class label.
#
# > CNN computes feature maps
#
# Certain types of multilayer NNs, and in particular, deep convolutional NNs, construct a so-called ***feature hierarchy*** by combining the low-level features in a layer-wise fashion to form high-level features.
#
# ### CNNs will usually perform very well on image-related tasks, and that's largely due to two important ideas:
# - **Sparse connectivity**: A single element in the feature map is connected to only a small patch of pixels. (This is very different from connecting to the whole input image as in the case of perceptrons. You may find it useful to look back and compare how we implemented a **fully connected network** that connected to the whole image in *Chapter 12*, *Implementing a Multilayer Artificial Neural Network from Scratch*.)
# - **Parameter-sharing**: *The same weights* are used for different patches of the input image.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Computational Vision at CALTECH
#
# 캘리포니아 공과대학(caltech)에서 ML을 위해 배포하고 있는 이미지 세트
#
# ## Catltech101
# 약 131M 정도
#
# [Url of Caltech 101](http://www.vision.caltech.edu/Image_Datasets/Caltech101/Caltech101.html#Download): www.vision.caltech.edu/Image_Datasets/Caltech101/

# %% [markdown]
# ### Mount your google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !ls -al
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Jul  9 00:48 .
# drwxr-xr-x 1 root root 4096 Jul  9 00:45 ..
# drwxr-xr-x 4 root root 4096 Jul  1 13:41 .config
# drwx------ 6 root root 4096 Jul  9 00:48 drive
# drwxr-xr-x 1 root root 4096 Jul  1 13:42 sample_data

# %% [markdown]
# 다운로드 받은 caltech101 데이터를 업로드해놓은 구글 드라이브 경로를 얻고, 현재의 working directory로 카피

# %%
# !mkdir image

# %%
# !cp /content/drive/MyDrive/_[10]Lecture/MachineLearning/datasets/101_ObjectCategories.tar.gz ./image/

# %%
#!cd image
# %cd image
# !ls -al
# Out:
# /content/image
# total 128664
# drwxr-xr-x 2 root root      4096 Jul  9 00:52 .
# drwxr-xr-x 1 root root      4096 Jul  9 00:51 ..
# -rw------- 1 root root 131740031 Jul  9 00:52 101_ObjectCategories.tar.gz

# %% [markdown]
# 압축 해제하여 사용할 데이터셋을 설정.

# %%
# !tar xvfz ./101_ObjectCategories.tar.gz > test.log

# %%
os.getcwd()
# Out:
# '/content/image'

# %%
import os
os.chdir('../')
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# * 101가지 클래스를 전부를 분류하도록 학습하기에는 시간이 오래 걸림.
# * 때문에 아래 코드 처럼, 5개의 클래스만 사용하기로 함.
#   * chair (의자)
#   * camera (카메라)
#   * butterfly (나비)
#   * elephant (코끼리)
#   * flamingo (플라밍고)

# %%
import numpy as np
import os, glob
import cv2 
from sklearn.model_selection import train_test_split

caltech_dir = './image/101_ObjectCategories'
categories = ['chair', 'camera', 'butterfly', 'elephant', 'flamingo']
num_classes = len(categories)

# %% [markdown]
# # Prepare inputs
#
# We prepare dataset for training.
#
# * The input data are resized to uniform $64 \times 64$.
# * The labels are put into one-hot (a.k.a. categorical) encoding.

# %%
w = 64
h = 64
pixels = w*h*3

X = []
Y = []

for idx, cat in enumerate(categories):
  label = [0 for i in range(num_classes)]
  label[idx] = 1
  print(f'label of {cat}: {label}')

  image_dir = os.path.join(caltech_dir,cat)
  print(image_dir)
  files = glob.glob(os.path.join(image_dir,'*.jpg'))

  for i, f in enumerate(files):
    
    img = cv2.imread(f) #img = Image.open(f)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #img = img.convert('RGB')
    img = cv2.resize(img, (w,h))
    
    X.append(img)
    Y.append(label)    

# convert to ndarray!
X = np.array(X)
Y = np.array(Y)
# Out:
# label of chair: [1, 0, 0, 0, 0]
# ./image/101_ObjectCategories/chair
# label of camera: [0, 1, 0, 0, 0]
# ./image/101_ObjectCategories/camera
# label of butterfly: [0, 0, 1, 0, 0]
# ./image/101_ObjectCategories/butterfly
# label of elephant: [0, 0, 0, 1, 0]
# ./image/101_ObjectCategories/elephant
# label of flamingo: [0, 0, 0, 0, 1]
# ./image/101_ObjectCategories/flamingo

# %%
X.shape
# Out:
# (334, 64, 64, 3)

# %%
Y.shape
# Out:
# (334, 5)

# %% [markdown]
# # Divide train and test dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y)

xy = (X_train,X_test,y_train,y_test)
np.save('./image/5cat.npy',xy)
print('ok!', np.shape)
print('# of train samples:',len(X_train))
print('# of test samples:', len(X_test))
# Out:
# ok! <function shape at 0x7f7e211c07a0>
# # of train samples: 250
# # of test samples: 84
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
84/(250+84)
# Out:
# 0.25149700598802394

# %%
from google.colab.patches import cv2_imshow

idx = 10
print(y_train[idx])
# cv2_imshow(X_train[idx],cv2.COLOR_BGR2RGB)
cv2_imshow(cv2.cvtColor(X_train[idx],cv2.COLOR_BGR2RGB))
# Out:
# [0 0 1 0 0]
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7DF0694B50>

# %% [markdown]
# # Convert TFData Souce from Numpy Arrays

# %%
import tensorflow_datasets as tfds
import tensorflow as tf

train_dataset = tf.data.Dataset.from_tensor_slices((X_train,y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test,y_test))
train_dataset
# Out:
# <TensorSliceDataset shapes: ((64, 64, 3), (5,)), types: (tf.uint8, tf.int64)>

# %%
batch_train_dataset = train_dataset.batch(batch_size=8,drop_remainder=True)
batch_test_dataset = test_dataset.batch(batch_size=8,drop_remainder=True)
batch_train_dataset
# Out:
# <BatchDataset shapes: ((8, 64, 64, 3), (8, 5)), types: (tf.uint8, tf.int64)>

# %%
range(10)
# Out:
# range(0, 10)

# %% [markdown]
# # Visualizaing the data
#
# The following code shows the first 9 images with their labels.

# %%
def format_label(label):
  string_label = categories[tf.math.argmax(label)]
  return string_label

# %%
import matplotlib.pyplot as plt

for i, (image, label) in enumerate(train_dataset.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.title(f"{format_label(label)}")
    plt.axis("off")

# %% [markdown]
# # DNN for Our Example

# %%
from tensorflow.keras import layers, models

# %%
inputs = layers.Input(shape=(w,h,3))
x = layers.Conv2D(32,3,3,
                  #activation='relu',
                  padding='same')(inputs)
x = layers.Activation('relu')(x)
x = layers.MaxPooling2D(pool_size=(2,2))(x)
x = layers.Dropout(0.25)(x)

x = layers.Conv2D(64,3,3,
                  #activation='relu',
                  padding='same')(x)
x = layers.Activation('relu')(x)
x = layers.Conv2D(64,3,3,                  
                  #activation='relu',
                  padding='same')(x)                  
x = layers.MaxPooling2D(pool_size=(2,2))(x)
x = layers.Dropout(0.25)(x)

x = layers.Flatten()(x)
x = layers.Dense(512)(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(num_classes)(x)
outputs = layers.Activation('softmax')(x)

model = models.Model(inputs = inputs, 
                     outputs= outputs)
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()

epochs = 40 # @param {type:'slider', min:10, max:100}
hist = model.fit(
    batch_train_dataset,
    #X_train, y_train,
    epochs=epochs,
    validation_data = batch_test_dataset,
    verbose=2)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 22, 22, 32)        896
# _________________________________________________________________
# activation_8 (Activation)    (None, 22, 22, 32)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 64)          18496
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 64)          36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               33280
# _________________________________________________________________
# activation_10 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 2565
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 92,165
# Trainable params: 92,165
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 31/31 - 1s - loss: 8.9712 - accuracy: 0.1532 - val_loss: 1.7190 - val_accuracy: 0.1875
# Epoch 2/40
# 31/31 - 0s - loss: 2.2146 - accuracy: 0.3145 - val_loss: 1.5930 - val_accuracy: 0.2875
# Epoch 3/40
# 31/31 - 0s - loss: 2.0030 - accuracy: 0.2540 - val_loss: 1.5693 - val_accuracy: 0.2250
# Epoch 4/40
# 31/31 - 0s - loss: 1.7155 - accuracy: 0.2782 - val_loss: 1.5538 - val_accuracy: 0.3250
# Epoch 5/40
# 31/31 - 0s - loss: 1.6234 - accuracy: 0.3145 - val_loss: 1.5497 - val_accuracy: 0.3000
# Epoch 6/40
# 31/31 - 0s - loss: 1.6258 - accuracy: 0.3266 - val_loss: 1.5096 - val_accuracy: 0.2500
# Epoch 7/40
# 31/31 - 0s - loss: 1.5831 - accuracy: 0.3105 - val_loss: 1.5250 - val_accuracy: 0.3125
# Epoch 8/40
# 31/31 - 0s - loss: 1.4480 - accuracy: 0.3710 - val_loss: 1.4987 - val_accuracy: 0.2500
# Epoch 9/40
# 31/31 - 0s - loss: 1.4350 - accuracy: 0.3629 - val_loss: 1.4889 - val_accuracy: 0.3000
# Epoch 10/40
# 31/31 - 0s - loss: 1.3291 - accuracy: 0.4435 - val_loss: 1.4627 - val_accuracy: 0.3250
# Epoch 11/40
# 31/31 - 0s - loss: 1.4013 - accuracy: 0.3710 - val_loss: 1.4001 - val_accuracy: 0.3750
# Epoch 12/40
# 31/31 - 0s - loss: 1.3288 - accuracy: 0.4153 - val_loss: 1.4306 - val_accuracy: 0.3375
# Epoch 13/40
# 31/31 - 0s - loss: 1.2516 - accuracy: 0.4597 - val_loss: 1.3590 - val_accuracy: 0.4250
# Epoch 14/40
# 31/31 - 0s - loss: 1.2248 - accuracy: 0.5403 - val_loss: 1.3664 - val_accuracy: 0.4500
# Epoch 15/40
# 31/31 - 0s - loss: 1.1183 - accuracy: 0.5363 - val_loss: 1.3004 - val_accuracy: 0.4375
# Epoch 16/40
# 31/31 - 0s - loss: 1.2091 - accuracy: 0.4839 - val_loss: 1.3016 - val_accuracy: 0.4875
# Epoch 17/40
# 31/31 - 0s - loss: 1.1718 - accuracy: 0.5323 - val_loss: 1.3256 - val_accuracy: 0.4250
# Epoch 18/40
# 31/31 - 0s - loss: 1.0651 - accuracy: 0.5968 - val_loss: 1.3221 - val_accuracy: 0.4875
# Epoch 19/40
# 31/31 - 0s - loss: 0.9561 - accuracy: 0.5927 - val_loss: 1.3923 - val_accuracy: 0.5375
# Epoch 20/40
# 31/31 - 0s - loss: 0.8862 - accuracy: 0.6573 - val_loss: 1.2736 - val_accuracy: 0.5500
# Epoch 21/40
# 31/31 - 0s - loss: 0.8776 - accuracy: 0.6613 - val_loss: 1.5273 - val_accuracy: 0.4500
# Epoch 22/40
# 31/31 - 0s - loss: 0.9265 - accuracy: 0.6411 - val_loss: 1.2607 - val_accuracy: 0.5750
# Epoch 23/40
# 31/31 - 0s - loss: 0.8132 - accuracy: 0.6653 - val_loss: 1.6521 - val_accuracy: 0.4500
# Epoch 24/40
# 31/31 - 0s - loss: 0.7843 - accuracy: 0.7097 - val_loss: 1.2251 - val_accuracy: 0.5875
# Epoch 25/40
# 31/31 - 0s - loss: 0.6739 - accuracy: 0.7419 - val_loss: 1.4736 - val_accuracy: 0.5000
# Epoch 26/40
# 31/31 - 0s - loss: 0.6495 - accuracy: 0.7742 - val_loss: 1.3535 - val_accuracy: 0.5250
# Epoch 27/40
# 31/31 - 0s - loss: 0.5894 - accuracy: 0.7903 - val_loss: 1.3416 - val_accuracy: 0.5625
# Epoch 28/40
# 31/31 - 0s - loss: 0.5604 - accuracy: 0.8105 - val_loss: 1.4990 - val_accuracy: 0.5500
# Epoch 29/40
# 31/31 - 0s - loss: 0.4919 - accuracy: 0.8185 - val_loss: 1.5242 - val_accuracy: 0.5125
# Epoch 30/40
# 31/31 - 0s - loss: 0.3905 - accuracy: 0.8629 - val_loss: 1.5679 - val_accuracy: 0.5375
# Epoch 31/40
# 31/31 - 0s - loss: 0.4926 - accuracy: 0.8266 - val_loss: 1.3854 - val_accuracy: 0.5875
# Epoch 32/40
# 31/31 - 0s - loss: 0.3367 - accuracy: 0.8831 - val_loss: 1.4181 - val_accuracy: 0.5625
# Epoch 33/40
# 31/31 - 0s - loss: 0.3517 - accuracy: 0.8911 - val_loss: 1.6023 - val_accuracy: 0.5500
# Epoch 34/40
# 31/31 - 0s - loss: 0.3508 - accuracy: 0.8589 - val_loss: 1.4613 - val_accuracy: 0.5625
# Epoch 35/40
# 31/31 - 0s - loss: 0.3384 - accuracy: 0.8911 - val_loss: 1.4666 - val_accuracy: 0.6000
# Epoch 36/40
# 31/31 - 0s - loss: 0.2814 - accuracy: 0.8952 - val_loss: 1.9923 - val_accuracy: 0.5250
# Epoch 37/40
# 31/31 - 0s - loss: 0.2933 - accuracy: 0.9032 - val_loss: 1.8480 - val_accuracy: 0.4875
# Epoch 38/40
# 31/31 - 0s - loss: 0.2579 - accuracy: 0.8952 - val_loss: 1.8162 - val_accuracy: 0.5375
# Epoch 39/40
# 31/31 - 0s - loss: 0.2986 - accuracy: 0.9073 - val_loss: 1.7987 - val_accuracy: 0.5125
# Epoch 40/40
# 31/31 - 0s - loss: 0.2040 - accuracy: 0.9355 - val_loss: 1.9780 - val_accuracy: 0.5000

# %% [markdown]
# * 매우 빠른 시간에 끝나고, 90% 수준의 accuracy를 보임.
# * 하지만 validation dataset에서의 accuracy는 그리 좋지 않음.
# * 즉, overfit임...

# %%
score = model.evaluate(batch_test_dataset)
print(f'loss={score[0]}')
print(f'accuracy={score[1]}')
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 1.9780 - accuracy: 0.5000
# loss=1.9779632091522217
# accuracy=0.5

# %%
import matplotlib.pyplot as plt


def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()

plot_hist(hist)

# %%
pres = model.predict(X_test)
print(pres.shape)

error_img_dir = os.path.join('.','error')
try: 
  os.mkdir('error')
except FileExistsError as e:
  print(e)

cnt = 0
for idx,(pre_prob,ans_onehot) in enumerate(zip(pres, y_test)):  
  pre = pre_prob.argmax()
  ans = ans_onehot.argmax()
  if pre == ans:
    continue
  cnt += 1
  print(f'Error: predicted {format_label(pre_prob)} != label {format_label(ans_onehot)}')
  fstr = os.path.join(error_img_dir,f'{idx:02d}-{format_label(pre_prob)}-ne-{format_label(ans_onehot)}.png')
  cv2.imwrite(fstr, X_test[idx])

print(f'Error Rate = {cnt}/{len(X_test)}')
# Out:
# (84, 5)
# Error: predicted butterfly != label camera
# Error: predicted flamingo != label butterfly
# Error: predicted butterfly != label flamingo
# Error: predicted camera != label butterfly
# Error: predicted flamingo != label chair
# Error: predicted elephant != label camera
# Error: predicted flamingo != label chair
# Error: predicted chair != label elephant
# Error: predicted elephant != label butterfly
# Error: predicted camera != label flamingo
# Error: predicted butterfly != label elephant
# Error: predicted chair != label flamingo
# Error: predicted elephant != label flamingo
# Error: predicted elephant != label chair
# Error: predicted flamingo != label chair
# Error: predicted butterfly != label flamingo
# Error: predicted elephant != label chair
# Error: predicted elephant != label butterfly
# Error: predicted elephant != label camera
# Error: predicted camera != label chair
# Error: predicted butterfly != label elephant
# Error: predicted butterfly != label chair
# Error: predicted elephant != label camera
# Error: predicted chair != label butterfly
# Error: predicted elephant != label camera
# Error: predicted elephant != label chair
# Error: predicted butterfly != label flamingo
# Error: predicted chair != label flamingo
# Error: predicted butterfly != label chair
# Error: predicted chair != label butterfly
# Error: predicted elephant != label chair
# Error: predicted camera != label chair
# Error: predicted elephant != label camera
# Error: predicted chair != label elephant
# Error: predicted butterfly != label chair
# Error: predicted butterfly != label chair
# Error: predicted elephant != label camera
# Error: predicted camera != label elephant
# Error: predicted flamingo != label butterfly
# Error: predicted elephant != label camera
# Error Rate = 40/84

# %% [markdown]
# # Export and Import Model Structure and Weights
#
# A Keras model consists of multiple components:
#
# * The **architecture**, or configuration, which specifies what layers the model contain, and how they're connected.
# * A set of **weights values** (the "state of the model").
# * An optimizer (defined by compiling the model).
# * A set of losses and metrics (defined by compiling the model or calling `add_loss()` or `add_metric()`).
#
# The Keras API makes it possible to save all of these pieces to disk at once, or to only selectively save some of them:
#
# * Saving everything into a single archive in the ***TensorFlow `SavedModel` format*** (or in the older Keras H5 format). This is the standard practice.
# * Saving the architecture / configuration only, typically as a JSON file.
# * Saving the weights values only. This is generally used when training the model.
#
# [Ref.] https://www.tensorflow.org/guide/keras/save_and_serialize

# %%
from tensorflow.keras import models
# Calling `save('my_model')` creates a SavedModel folder `my_model`.
model.save("my_model")

# It can be used to reconstruct the model identically.
reconstructed_model = models.load_model("my_model")

# Let's check:
np.testing.assert_allclose(
    model.predict(X_test), reconstructed_model.predict(X_test)
)

# ============================================================
# The reconstructed model is already compiled and has retained the optimizer
# state, so training can resume:
reconstructed_model.fit(batch_train_dataset) # batch를 잡고...
#reconstructed_model.fit(X_test, X_test)
# Out:
# INFO:tensorflow:Assets written to: my_model/assets
# 31/31 [==============================] - 1s 3ms/step - loss: 0.3031 - accuracy: 0.8911

# %% [markdown]
# ### What the SavedModel contains

# %% [markdown]
# Calling `model.save('my_model')` creates a folder named `my_model`, containing the following:

# %%
# !ls my_model
# Out:
# assets	keras_metadata.pb  saved_model.pb  variables

# %% [markdown]
# The model ***architecture***, and training configuration (including the `optimizer`, `losses`, and `metrics`) are stored in `saved_model.pb`.
#
# The ***weights*** are saved in the `variables/` directory.
#
# For detailed information on the ***SavedModel*** format,
# see the [SavedModel guide (The SavedModel format on disk)](https://www.tensorflow.org/guide/saved_model#the_savedmodel_format_on_disk).

# %% [markdown]
# ### Keras H5 format

# %% [markdown]
# Keras also supports saving a ***single HDF5 file*** containing
# * the model's architecture,
# weights values, and
# compile() information.
#
# It is a light-weight alternative to `SavedModel`.

# %%
# Calling `save('my_model.h5')` creates a h5 file `my_model.h5`.
model.save("my_h5_model.h5")

# It can be used to reconstruct the model identically.
reconstructed_model = models.load_model("my_h5_model.h5")

# Let's check:
np.testing.assert_allclose(
    model.predict(X_test), reconstructed_model.predict(X_test)
)

# %% [markdown]
# #### Limitations
#
# Compared to the `SavedModel` format, there are two things that don't get included in the ***H5 file***:
#
# * **External losses & metrics added via `model.add_loss()` & `model.add_metric()` are not saved (unlike SavedModel).** <br/> If you have such losses & metrics on your model and you want to resume training, you need to add these losses back yourself **after loading the model**. <br/>
# Note that this does not apply to losses/metrics created inside layers via `self.add_loss()` & `self.add_metric()`. <br/>As long as the layer gets loaded, these losses & metrics are kept, since they are part of the call method of the layer.
# * The **computation graph of custom objects** such as custom layers is not included in the saved file. At loading time, Keras will need access to the Python classes/functions of these objects in order to reconstruct the model. See Custom objects.

# %% [markdown]
# ### Saving the architecture

# %% [markdown]
# The model's ***configuration*** (or ***architecture***) specifies what layers the model contains, and how these layers are connected*. If you have the configuration of a model, then the model can be created with a freshly initialized state for the weights and no compilation information.
#
# > Note this only applies to models defined using the ***functional*** or ***Sequential*** APIs not subclassed models.

# %%
import tensorflow.keras as keras
# Sequential model example
model = keras.Sequential([keras.layers.InputLayer((32,)), keras.layers.Dense(1)])

config = model.get_config()
new_model = keras.Sequential.from_config(config)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Functional model example
inputs = keras.Input((32,))
outputs = keras.layers.Dense(1)(inputs)
model = keras.Model(inputs, outputs)

config = model.get_config()
new_model = keras.Model.from_config(config)

# %% [markdown]
# ### Saving & loading only the model's weights values

# %% [markdown]
# You can choose to only save & load a model's ***weights***. <br/>
# This can be useful if:
#
# * You only need the model for inference:
#   * in this case you won't need to ***restart training***,
#   * so you don't need *the compilation information* or *optimizer state*.
# * You are doing ***transfer learning***:
#   * in this case you will be training a new model reusing the state of a prior model,
#   * so you don't need *the compilation information* of *the prior model*.
#
# #### APIs for saving weights to disk & loading them back
#
# Weights can be saved to disk by calling `model.save_weights` in the following formats:
# * TensorFlow Checkpoint
# * HDF5
#
# The default format for `model.save_weights` is TensorFlow checkpoint. There are two ways to specify the save format:
#
# *  `save_format` argument: Set the value to `save_format="tf"` or `save_format="h5"`.
# * `path` argument: If the path ends with `.h5` or `.hdf5`, then the HDF5 format is used. Other suffixes will result in a TensorFlow checkpoint unless `save_format` is set.
#
# There is also an option of retrieving weights as in-memory numpy arrays.

# %%
model.save_weights("ckpt")
load_status = model.load_weights("ckpt")

# `assert_consumed` can be used as validation that all variable values have been
# restored from the checkpoint. See `tf.train.Checkpoint.restore` for other
# methods in the Status object.
load_status.assert_consumed()

# %% [markdown]
# # Keras Applications
#
# Keras Applications are ***deep learning models*** that are made available alongside `pre-trained weights`.
#
# These models can be used for
# * prediction,
# * feature extraction, and
# * fine-tuning.
#
# Weights are downloaded automatically when instantiating a model. They are stored at `~/.keras/models/.`
#
# Upon instantiation, the models will be built according to the image data format set in your Keras configuration file at `~/.keras/keras.json`. For instance, if you have set `image_data_format=channels_last`, then any model loaded from this repository will get built according to the TensorFlow data format convention, `"Height-Width-Depth"`.
#
# Ref. : https://keras.io/api/applications/

# %% [markdown]
# # Keras implementation of EfficientNet
#
# An implementation of ***EfficientNet B0 to B7*** has been shipped with `tf.keras` since TF2.3. To use `EfficientNetB0` for classifying 1000 classes of images from imagenet, run:

# %%
from tensorflow.keras.applications import EfficientNetB0
model = EfficientNetB0(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0.h5
# 21839872/21834768 [==============================] - 1s 0us/step

# %% [markdown]
# * This model takes input images of `shape (224, 224, 3)`, and the input data should range `[0, 255]`.
# * Normalization is included as part of the model.

# %% [markdown]
# # Example: ResNet50 for Our Example

# %%
from tensorflow.keras.applications.resnet50 import  ResNet50

inputs = layers.Input(shape=(w,h,3))
outputs = ResNet50(include_top=True, 
                         weights=None,
                         input_shape=(w,h,3),
                         classes=num_classes)(inputs)

model = models.Model(inputs = inputs, outputs= outputs)
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()

epochs = 40 # @param {type:'slider', min:10, max:100}

# hist = model.fit(X_train, y_train,
#                  epochs=epochs,
#                  #validation_data = (X_test, y_test),
#                  )
hist = model.fit(batch_train_dataset,
                 epochs=epochs,
                 validation_data = batch_test_dataset,
                 verbose=2)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# resnet50 (Functional)        (None, 5)                 23597957
# =================================================================
# Total params: 23,597,957
# Trainable params: 23,544,837
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/40
# 31/31 - 7s - loss: 3.0804 - accuracy: 0.2661 - val_loss: 8.7445 - val_accuracy: 0.2750
# Epoch 2/40
# 31/31 - 1s - loss: 1.7123 - accuracy: 0.4355 - val_loss: 4.1862 - val_accuracy: 0.2500
# Epoch 3/40
# 31/31 - 1s - loss: 0.7065 - accuracy: 0.7782 - val_loss: 8.0013 - val_accuracy: 0.2500
# Epoch 4/40
# 31/31 - 1s - loss: 1.7297 - accuracy: 0.4879 - val_loss: 3.5601 - val_accuracy: 0.2875
# Epoch 5/40
# 31/31 - 1s - loss: 0.8861 - accuracy: 0.6976 - val_loss: 2.8263 - val_accuracy: 0.2500
# Epoch 6/40
# 31/31 - 1s - loss: 0.9159 - accuracy: 0.7460 - val_loss: 4.7356 - val_accuracy: 0.3000
# Epoch 7/40
# 31/31 - 1s - loss: 0.8340 - accuracy: 0.7661 - val_loss: 3.4750 - val_accuracy: 0.4250
# Epoch 8/40
# 31/31 - 1s - loss: 0.7509 - accuracy: 0.7984 - val_loss: 3.2096 - val_accuracy: 0.4000
# Epoch 9/40
# 31/31 - 1s - loss: 0.4036 - accuracy: 0.8508 - val_loss: 3.9880 - val_accuracy: 0.4000
# Epoch 10/40
# 31/31 - 1s - loss: 0.1814 - accuracy: 0.9435 - val_loss: 3.8608 - val_accuracy: 0.4250
# Epoch 11/40
# 31/31 - 1s - loss: 0.3996 - accuracy: 0.9113 - val_loss: 5.1319 - val_accuracy: 0.4500
# Epoch 12/40
# 31/31 - 1s - loss: 0.3283 - accuracy: 0.9113 - val_loss: 5.3758 - val_accuracy: 0.4125
# Epoch 13/40
# 31/31 - 1s - loss: 0.2442 - accuracy: 0.9153 - val_loss: 4.5974 - val_accuracy: 0.4375
# Epoch 14/40
# 31/31 - 1s - loss: 0.3401 - accuracy: 0.9153 - val_loss: 3.8663 - val_accuracy: 0.4750
# Epoch 15/40
# 31/31 - 1s - loss: 0.4489 - accuracy: 0.9113 - val_loss: 10.2338 - val_accuracy: 0.3750
# Epoch 16/40
# 31/31 - 1s - loss: 0.3475 - accuracy: 0.9355 - val_loss: 2.8096 - val_accuracy: 0.5000
# Epoch 17/40
# 31/31 - 1s - loss: 0.3734 - accuracy: 0.9073 - val_loss: 2.9599 - val_accuracy: 0.5500
# Epoch 18/40
# 31/31 - 1s - loss: 0.3869 - accuracy: 0.8790 - val_loss: 4.0161 - val_accuracy: 0.4875
# Epoch 19/40
# 31/31 - 1s - loss: 0.4346 - accuracy: 0.8952 - val_loss: 4.0172 - val_accuracy: 0.5250
# Epoch 20/40
# 31/31 - 1s - loss: 0.4480 - accuracy: 0.8952 - val_loss: 2.8574 - val_accuracy: 0.6000
# Epoch 21/40
# 31/31 - 1s - loss: 0.1883 - accuracy: 0.9435 - val_loss: 3.2610 - val_accuracy: 0.4875
# Epoch 22/40
# 31/31 - 1s - loss: 0.2017 - accuracy: 0.9274 - val_loss: 4.6821 - val_accuracy: 0.4750
# Epoch 23/40
# 31/31 - 1s - loss: 0.1287 - accuracy: 0.9597 - val_loss: 6.9849 - val_accuracy: 0.4125
# Epoch 24/40
# 31/31 - 1s - loss: 0.0422 - accuracy: 0.9879 - val_loss: 3.5803 - val_accuracy: 0.5375
# Epoch 25/40
# 31/31 - 1s - loss: 0.0230 - accuracy: 0.9960 - val_loss: 2.7742 - val_accuracy: 0.5750
# Epoch 26/40
# 31/31 - 1s - loss: 0.0161 - accuracy: 0.9919 - val_loss: 2.3959 - val_accuracy: 0.5875
# Epoch 27/40
# 31/31 - 1s - loss: 7.0434e-04 - accuracy: 1.0000 - val_loss: 2.7830 - val_accuracy: 0.6125
# Epoch 28/40
# 31/31 - 1s - loss: 5.4945e-04 - accuracy: 1.0000 - val_loss: 2.6530 - val_accuracy: 0.6000
# Epoch 29/40
# 31/31 - 1s - loss: 3.6192e-04 - accuracy: 1.0000 - val_loss: 2.6123 - val_accuracy: 0.6125
# Epoch 30/40
# 31/31 - 1s - loss: 2.8824e-04 - accuracy: 1.0000 - val_loss: 2.5924 - val_accuracy: 0.6000
# Epoch 31/40
# 31/31 - 1s - loss: 2.4347e-04 - accuracy: 1.0000 - val_loss: 2.5888 - val_accuracy: 0.5875
# Epoch 32/40
# 31/31 - 1s - loss: 2.1227e-04 - accuracy: 1.0000 - val_loss: 2.5906 - val_accuracy: 0.5750
# Epoch 33/40
# 31/31 - 1s - loss: 1.8885e-04 - accuracy: 1.0000 - val_loss: 2.5937 - val_accuracy: 0.5875
# Epoch 34/40
# 31/31 - 1s - loss: 1.7040e-04 - accuracy: 1.0000 - val_loss: 2.5979 - val_accuracy: 0.5875
# Epoch 35/40
# 31/31 - 1s - loss: 1.5538e-04 - accuracy: 1.0000 - val_loss: 2.6014 - val_accuracy: 0.5875
# Epoch 36/40
# 31/31 - 1s - loss: 1.4287e-04 - accuracy: 1.0000 - val_loss: 2.6048 - val_accuracy: 0.5875
# Epoch 37/40
# 31/31 - 1s - loss: 1.3225e-04 - accuracy: 1.0000 - val_loss: 2.6081 - val_accuracy: 0.5875
# Epoch 38/40
# 31/31 - 1s - loss: 1.2308e-04 - accuracy: 1.0000 - val_loss: 2.6117 - val_accuracy: 0.5875
# Epoch 39/40
# 31/31 - 1s - loss: 1.1508e-04 - accuracy: 1.0000 - val_loss: 2.6152 - val_accuracy: 0.5875
# Epoch 40/40
# 31/31 - 1s - loss: 1.0802e-04 - accuracy: 1.0000 - val_loss: 2.6185 - val_accuracy: 0.5875

# %% [markdown]
# * 1분 내에 학습 완료!
# * 하지만 역시 overfitting

# %% [markdown]
# # Example: EfficientNetB0 for Our Example.

# %% [markdown]
# ## From Scratch
#
# We build an EfficientNetB0 with 4 output classes, that is initialized from scratch:
#
# Note: the accuracy will increase very slowly and may overfit.

# %%
from tensorflow.keras.applications.efficientnet import  EfficientNetB0

inputs = layers.Input(shape=(w,h,3))
outputs = EfficientNetB0(include_top=True, 
                         weights=None,
                         input_shape=(w,h,3),
                         classes=num_classes)(inputs)

model = models.Model(inputs = inputs, outputs= outputs)
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()

epochs = 40 # @param {type:'slider', min:10, max:100}

# hist = model.fit(X_train, y_train,
#                  epochs=epochs,
#                  #validation_data = (X_test, y_test),
#                  )
hist = model.fit(batch_train_dataset,
                 epochs=epochs,
                 validation_data = batch_test_dataset,
                 verbose=2)
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, 5)                 4055976
# =================================================================
# Total params: 4,055,976
# Trainable params: 4,013,953
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/40
# 31/31 - 10s - loss: 6.6434 - accuracy: 0.2137 - val_loss: 1.6189 - val_accuracy: 0.2250
# Epoch 2/40
# 31/31 - 1s - loss: 4.8739 - accuracy: 0.3105 - val_loss: 1.8050 - val_accuracy: 0.2500
# Epoch 3/40
# 31/31 - 1s - loss: 3.4007 - accuracy: 0.4194 - val_loss: 2.8279 - val_accuracy: 0.2250
# Epoch 4/40
# 31/31 - 1s - loss: 2.0035 - accuracy: 0.5645 - val_loss: 1.8150 - val_accuracy: 0.2250
# Epoch 5/40
# 31/31 - 1s - loss: 1.5876 - accuracy: 0.6210 - val_loss: 2.0064 - val_accuracy: 0.2500
# Epoch 6/40
# 31/31 - 1s - loss: 1.8535 - accuracy: 0.6492 - val_loss: 2.3358 - val_accuracy: 0.2250
# Epoch 7/40
# 31/31 - 1s - loss: 1.7843 - accuracy: 0.7016 - val_loss: 3.1505 - val_accuracy: 0.2250
# Epoch 8/40
# 31/31 - 1s - loss: 1.7867 - accuracy: 0.6573 - val_loss: 2.0504 - val_accuracy: 0.2500
# Epoch 9/40
# 31/31 - 1s - loss: 1.1864 - accuracy: 0.7419 - val_loss: 3.0056 - val_accuracy: 0.2250
# Epoch 10/40
# 31/31 - 1s - loss: 1.5450 - accuracy: 0.7460 - val_loss: 1.9584 - val_accuracy: 0.1750
# Epoch 11/40
# 31/31 - 1s - loss: 1.5062 - accuracy: 0.7460 - val_loss: 2.4393 - val_accuracy: 0.2375
# Epoch 12/40
# 31/31 - 1s - loss: 1.1482 - accuracy: 0.7702 - val_loss: 3.2217 - val_accuracy: 0.1750
# Epoch 13/40
# 31/31 - 1s - loss: 0.7744 - accuracy: 0.8024 - val_loss: 2.4075 - val_accuracy: 0.2625
# Epoch 14/40
# 31/31 - 1s - loss: 0.9339 - accuracy: 0.8065 - val_loss: 2.7425 - val_accuracy: 0.2375
# Epoch 15/40
# 31/31 - 1s - loss: 0.9127 - accuracy: 0.8185 - val_loss: 3.4720 - val_accuracy: 0.2125
# Epoch 16/40
# 31/31 - 1s - loss: 0.6604 - accuracy: 0.8145 - val_loss: 2.4617 - val_accuracy: 0.2625
# Epoch 17/40
# 31/31 - 1s - loss: 0.4292 - accuracy: 0.8992 - val_loss: 3.2423 - val_accuracy: 0.2250
# Epoch 18/40
# 31/31 - 1s - loss: 0.4952 - accuracy: 0.8669 - val_loss: 4.1160 - val_accuracy: 0.3250
# Epoch 19/40
# 31/31 - 1s - loss: 0.5585 - accuracy: 0.9032 - val_loss: 3.6750 - val_accuracy: 0.2750
# Epoch 20/40
# 31/31 - 1s - loss: 0.1998 - accuracy: 0.9194 - val_loss: 3.2410 - val_accuracy: 0.2250
# Epoch 21/40
# 31/31 - 1s - loss: 0.3915 - accuracy: 0.9274 - val_loss: 2.8562 - val_accuracy: 0.2625
# Epoch 22/40
# 31/31 - 1s - loss: 0.8856 - accuracy: 0.8911 - val_loss: 7.0342 - val_accuracy: 0.2750
# Epoch 23/40
# 31/31 - 1s - loss: 0.3088 - accuracy: 0.9153 - val_loss: 2.5383 - val_accuracy: 0.3750
# Epoch 24/40
# 31/31 - 1s - loss: 0.5712 - accuracy: 0.8911 - val_loss: 8.3816 - val_accuracy: 0.2625
# Epoch 25/40
# 31/31 - 1s - loss: 0.9362 - accuracy: 0.8387 - val_loss: 16.8941 - val_accuracy: 0.3125
# Epoch 26/40
# 31/31 - 1s - loss: 0.7336 - accuracy: 0.8226 - val_loss: 34.6463 - val_accuracy: 0.3500
# Epoch 27/40
# 31/31 - 1s - loss: 0.6705 - accuracy: 0.8387 - val_loss: 14.0325 - val_accuracy: 0.3125
# Epoch 28/40
# 31/31 - 1s - loss: 0.3844 - accuracy: 0.8831 - val_loss: 6.8147 - val_accuracy: 0.3000
# Epoch 29/40
# 31/31 - 1s - loss: 0.2588 - accuracy: 0.9153 - val_loss: 10.8160 - val_accuracy: 0.2625
# Epoch 30/40
# 31/31 - 1s - loss: 0.3001 - accuracy: 0.9113 - val_loss: 5.5078 - val_accuracy: 0.2625
# Epoch 31/40
# 31/31 - 1s - loss: 0.3444 - accuracy: 0.8992 - val_loss: 5.3490 - val_accuracy: 0.2750
# Epoch 32/40
# 31/31 - 1s - loss: 0.2707 - accuracy: 0.9274 - val_loss: 3.0842 - val_accuracy: 0.3000
# Epoch 33/40
# 31/31 - 1s - loss: 0.3623 - accuracy: 0.9234 - val_loss: 4.5141 - val_accuracy: 0.3500
# Epoch 34/40
# 31/31 - 1s - loss: 0.1709 - accuracy: 0.9395 - val_loss: 4.8553 - val_accuracy: 0.3375
# Epoch 35/40
# 31/31 - 1s - loss: 0.3827 - accuracy: 0.9556 - val_loss: 3.8091 - val_accuracy: 0.3625
# Epoch 36/40
# 31/31 - 1s - loss: 0.2523 - accuracy: 0.9516 - val_loss: 4.5385 - val_accuracy: 0.3500
# Epoch 37/40
# 31/31 - 1s - loss: 0.4903 - accuracy: 0.9234 - val_loss: 10.0330 - val_accuracy: 0.3375
# Epoch 38/40
# 31/31 - 1s - loss: 0.5117 - accuracy: 0.8871 - val_loss: 7.7742 - val_accuracy: 0.3500
# Epoch 39/40
# 31/31 - 1s - loss: 0.3708 - accuracy: 0.8952 - val_loss: 9.7881 - val_accuracy: 0.2750
# Epoch 40/40
# 31/31 - 1s - loss: 0.2285 - accuracy: 0.9153 - val_loss: 7.4072 - val_accuracy: 0.3500

# %% [markdown]
# Training the model is relatively fast (takes only 54 seconds per epoch on GPU that is available on Colab). This might make it sounds easy to simply train EfficientNet on any dataset wanted from scratch.
# However, training EfficientNet on smaller datasets, especially those with lower resolution like our examples or CIFAR-100, faces the significant challenge of ***overfitting***.
#
# Hence training from scratch
# * requires very careful choice of ***hyperparameters*** and
# is difficult to find ***suitable regularization***.
#
# It would also be much more demanding in resources.
# > 우리의 경우처럼 데이터가 적은 경우 overfitting되기 쉬움.
#
# Plotting the training and validation accuracy makes it clear that validation accuracy stagnates at a low value.

# %%
plot_hist(hist)

# %% [markdown]
# # Data augmentation

# %% [markdown]
# 데이터의 양을 늘리기 위해 원본에 각종 변환을 적용하여 개수를 증강시키는 기법
#
# Ref. : https://journalofbigdata.springeropen.com/articles/10.1186/s40537-019-0197-0

# %% [markdown]
# We can use `preprocessing` layers APIs for **image augmentation**.
#
# https://keras.io/guides/preprocessing_layers/

# %%
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

img_augmentation = Sequential(
  [
    # representing lower and upper bound for rotating clockwise and counter-clockwise. 
    preprocessing.RandomRotation(factor=0.15), # a float represented as fraction of 2pi, ex :0.15 (= 54 degree!) 
    
    preprocessing.RandomTranslation(height_factor=0.1, # lower and upper bound for shifting vertically
                                    width_factor=0.1 #lower and upper bound for shifting horizontally.
                                    ),
    preprocessing.RandomFlip(), # Randomly flip each image horizontally and vertically.
    preprocessing.RandomContrast(factor=0.1),
  ],
  name="img_augmentation",
)

# %% [markdown]
# This `Sequential` model object can be used both
# * as a part of the model we later build, and
# * as a function to preprocess data before feeding into the model.
#
# Using them as function makes it easy to visualize the augmented images. Here we plot 9 examples of augmentation result of a given figure.

# %%
for image, label in train_dataset.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    aug_img = img_augmentation(tf.expand_dims(image, axis=0))
    plt.imshow(aug_img[0].numpy().astype("uint8"))
    
    plt.title(f"{format_label(label)}")
    plt.axis("off")

# %% [markdown]
# Data Augumentation은 데이터가 적을 때, generalization performance를 올릴 수 있는 가장 손쉬운 방법임.

# %%
from tensorflow.keras.applications.efficientnet import  EfficientNetB0
from tensorflow.keras import layers, models
from tensorflow.keras import layers

inputs = layers.Input(shape=(w,h,3))
x = img_augmentation(inputs)
outputs = EfficientNetB0(include_top=True, 
                         weights=None,
                         input_shape=(w,h,3),
                         classes=num_classes)(x)

model = models.Model(inputs = inputs, outputs= outputs)
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()

epochs = 200 # @param {type:'slider', min:10, max:200}
batch_size = 8

hist = model.fit(batch_train_dataset,
                 epochs=epochs,
                 validation_data = batch_test_dataset,
                 verbose=2)
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# img_augmentation (Sequential (None, 64, 64, 3)         0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, 5)                 4055976
# =================================================================
# Total params: 4,055,976
# Trainable params: 4,013,953
# Non-trainable params: 42,023
# _________________________________________________________________
# Epoch 1/200
# 31/31 - 9s - loss: 6.1105 - accuracy: 0.2661 - val_loss: 1.8383 - val_accuracy: 0.1750
# Epoch 2/200
# 31/31 - 1s - loss: 5.1619 - accuracy: 0.2379 - val_loss: 1.6171 - val_accuracy: 0.1750
# Epoch 3/200
# 31/31 - 1s - loss: 3.8530 - accuracy: 0.2339 - val_loss: 2.3551 - val_accuracy: 0.1750
# Epoch 4/200
# 31/31 - 1s - loss: 2.9411 - accuracy: 0.2419 - val_loss: 2.3058 - val_accuracy: 0.1750
# Epoch 5/200
# 31/31 - 1s - loss: 2.7077 - accuracy: 0.2984 - val_loss: 1.7014 - val_accuracy: 0.1750
# Epoch 6/200
# Epoch 51/200
# 31/31 - 1s - loss: 1.4903 - accuracy: 0.4718 - val_loss: 9.0491 - val_accuracy: 0.3250
# Epoch 52/200
# 31/31 - 1s - loss: 1.4474 - accuracy: 0.4960 - val_loss: 1.8012 - val_accuracy: 0.3500
# Epoch 53/200
# 31/31 - 1s - loss: 1.6275 - accuracy: 0.4718 - val_loss: 1.8316 - val_accuracy: 0.3125
# Epoch 54/200
# 31/31 - 1s - loss: 1.3715 - accuracy: 0.5282 - val_loss: 2.6527 - val_accuracy: 0.3375
# Epoch 55/200
# 31/31 - 1s - loss: 1.3240 - accuracy: 0.5242 - val_loss: 1.7046 - val_accuracy: 0.3375
# Epoch 56/200
# 31/31 - 1s - loss: 1.2375 - accuracy: 0.5323 - val_loss: 2.0301 - val_accuracy: 0.3375
# Epoch 57/200
# 31/31 - 1s - loss: 1.2260 - accuracy: 0.5363 - val_loss: 2.1897 - val_accuracy: 0.3500
# Epoch 58/200
# 31/31 - 1s - loss: 1.2772 - accuracy: 0.5121 - val_loss: 2.3448 - val_accuracy: 0.3500
# Epoch 59/200
# 31/31 - 1s - loss: 1.3640 - accuracy: 0.5282 - val_loss: 1.9043 - val_accuracy: 0.3750
# Epoch 60/200
# 31/31 - 1s - loss: 1.2751 - accuracy: 0.5565 - val_loss: 4.1923 - val_accuracy: 0.4250
# Epoch 61/200
# 31/31 - 1s - loss: 1.4181 - accuracy: 0.4879 - val_loss: 1.4824 - val_accuracy: 0.3625
# Epoch 62/200
# 31/31 - 1s - loss: 1.6087 - accuracy: 0.4637 - val_loss: 1.4336 - val_accuracy: 0.3875
# Epoch 63/200
# 31/31 - 1s - loss: 1.2764 - accuracy: 0.5000 - val_loss: 1.5164 - val_accuracy: 0.3750
# Epoch 64/200
# 31/31 - 1s - loss: 1.4217 - accuracy: 0.5242 - val_loss: 14.3526 - val_accuracy: 0.3750
# Epoch 65/200
# 31/31 - 1s - loss: 1.2613 - accuracy: 0.5282 - val_loss: 6.1959 - val_accuracy: 0.3625
# Epoch 66/200
# 31/31 - 1s - loss: 1.3571 - accuracy: 0.5121 - val_loss: 3.9444 - val_accuracy: 0.3500
# Epoch 67/200
# 31/31 - 1s - loss: 1.3662 - accuracy: 0.5282 - val_loss: 2.5151 - val_accuracy: 0.3500
# Epoch 68/200
# 31/31 - 1s - loss: 1.1786 - accuracy: 0.5726 - val_loss: 2.5565 - val_accuracy: 0.3750
# Epoch 69/200
# 31/31 - 1s - loss: 1.2950 - accuracy: 0.5242 - val_loss: 2.8724 - val_accuracy: 0.3125
# Epoch 70/200
# 31/31 - 1s - loss: 1.2228 - accuracy: 0.5806 - val_loss: 2.8656 - val_accuracy: 0.3875
# Epoch 71/200
# 31/31 - 1s - loss: 1.2282 - accuracy: 0.5202 - val_loss: 2.7529 - val_accuracy: 0.4000
# Epoch 72/200
# 31/31 - 1s - loss: 1.1045 - accuracy: 0.6129 - val_loss: 2.6902 - val_accuracy: 0.3500
# Epoch 73/200
# 31/31 - 1s - loss: 0.4475 - accuracy: 0.8185 - val_loss: 2.1152 - val_accuracy: 0.4000
# Epoch 185/200
# 31/31 - 1s - loss: 0.4987 - accuracy: 0.8387 - val_loss: 1.9221 - val_accuracy: 0.4750
# Epoch 186/200
# 31/31 - 1s - loss: 0.4522 - accuracy: 0.8629 - val_loss: 1.6390 - val_accuracy: 0.4875
# Epoch 187/200
# 31/31 - 1s - loss: 0.3693 - accuracy: 0.8508 - val_loss: 1.9091 - val_accuracy: 0.5125
# Epoch 188/200
# 31/31 - 1s - loss: 0.4466 - accuracy: 0.8427 - val_loss: 2.0554 - val_accuracy: 0.5375
# Epoch 189/200
# 31/31 - 1s - loss: 0.3116 - accuracy: 0.8790 - val_loss: 2.0583 - val_accuracy: 0.5500
# Epoch 190/200
# 31/31 - 1s - loss: 0.4598 - accuracy: 0.8347 - val_loss: 2.5101 - val_accuracy: 0.4750
# Epoch 191/200
# 31/31 - 1s - loss: 0.3516 - accuracy: 0.8508 - val_loss: 2.9437 - val_accuracy: 0.5250
# Epoch 192/200
# 31/31 - 1s - loss: 0.4197 - accuracy: 0.8831 - val_loss: 2.5658 - val_accuracy: 0.4875
# Epoch 193/200
# 31/31 - 1s - loss: 0.4811 - accuracy: 0.8347 - val_loss: 2.8272 - val_accuracy: 0.4375
# Epoch 194/200
# 31/31 - 1s - loss: 0.1942 - accuracy: 0.9597 - val_loss: 1.8818 - val_accuracy: 0.5750
# Epoch 195/200
# 31/31 - 1s - loss: 0.1740 - accuracy: 0.9435 - val_loss: 2.1096 - val_accuracy: 0.4625
# Epoch 196/200
# 31/31 - 1s - loss: 0.2234 - accuracy: 0.9395 - val_loss: 1.7905 - val_accuracy: 0.5000
# Epoch 197/200
# 31/31 - 1s - loss: 0.3338 - accuracy: 0.9032 - val_loss: 1.9858 - val_accuracy: 0.4625
# Epoch 198/200
# 31/31 - 1s - loss: 0.2817 - accuracy: 0.9113 - val_loss: 2.6546 - val_accuracy: 0.4250
# Epoch 199/200
# 31/31 - 1s - loss: 0.3140 - accuracy: 0.9153 - val_loss: 2.1442 - val_accuracy: 0.4500
# Epoch 200/200
# 31/31 - 1s - loss: 0.2806 - accuracy: 0.8831 - val_loss: 2.3807 - val_accuracy: 0.4500

# %%
plot_hist(hist)

# %% [markdown]
# # Transfer learning from pre-trained weights
#
# Here we initialize the model with pre-trained ImageNet weights, and we fine-tune it on our own dataset.

# %%
inputs = layers.Input(shape=(w,h,3))
x = img_augmentation(inputs)
model = EfficientNetB0(include_top=False, 
                       input_tensor=x, 
                       weights="imagenet")

# Freeze the pretrained weights
model.trainable = False

# Rebuild top
x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
x = layers.BatchNormalization()(x)

top_dropout_rate = 0.2
x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
outputs = layers.Dense(num_classes, 
                       activation="softmax", 
                       name="pred")(x)

# Compile
model = tf.keras.Model(inputs, outputs, name="EfficientNet")
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
model.compile(optimizer=optimizer, 
              loss="categorical_crossentropy", 
              metrics=["accuracy"])

epochs = 25  # @param {type: "slider", min:8, max:80}
hist = model.fit(batch_train_dataset,
                 epochs=epochs,
                 validation_data = batch_test_dataset,
                 verbose=2)
plot_hist(hist)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# Epoch 1/25
# 31/31 - 6s - loss: 1.8960 - accuracy: 0.5363 - val_loss: 0.6177 - val_accuracy: 0.7625
# Epoch 2/25
# 31/31 - 0s - loss: 0.9496 - accuracy: 0.7500 - val_loss: 0.4951 - val_accuracy: 0.8500
# Epoch 3/25
# 31/31 - 0s - loss: 1.0124 - accuracy: 0.7863 - val_loss: 0.5195 - val_accuracy: 0.8375
# Epoch 4/25
# 31/31 - 0s - loss: 0.7909 - accuracy: 0.8427 - val_loss: 0.4728 - val_accuracy: 0.8625
# Epoch 5/25
# 31/31 - 0s - loss: 0.8531 - accuracy: 0.7944 - val_loss: 0.4763 - val_accuracy: 0.8625
# Epoch 6/25
# 31/31 - 0s - loss: 0.5840 - accuracy: 0.8589 - val_loss: 0.7041 - val_accuracy: 0.8125
# Epoch 7/25
# 31/31 - 0s - loss: 0.8312 - accuracy: 0.8185 - val_loss: 0.5544 - val_accuracy: 0.8625
# Epoch 8/25
# 31/31 - 0s - loss: 0.6683 - accuracy: 0.8387 - val_loss: 0.8006 - val_accuracy: 0.8375
# Epoch 9/25
# 31/31 - 0s - loss: 1.0213 - accuracy: 0.8347 - val_loss: 0.6989 - val_accuracy: 0.8875
# Epoch 10/25
# 31/31 - 0s - loss: 0.7951 - accuracy: 0.8548 - val_loss: 1.2082 - val_accuracy: 0.7750
# Epoch 11/25
# 31/31 - 0s - loss: 0.8198 - accuracy: 0.8306 - val_loss: 0.7467 - val_accuracy: 0.9000
# Epoch 12/25
# 31/31 - 0s - loss: 0.5430 - accuracy: 0.8710 - val_loss: 0.7459 - val_accuracy: 0.8875
# Epoch 13/25
# 31/31 - 0s - loss: 0.8283 - accuracy: 0.8750 - val_loss: 0.9958 - val_accuracy: 0.8625
# Epoch 14/25
# 31/31 - 0s - loss: 0.6885 - accuracy: 0.8952 - val_loss: 1.0107 - val_accuracy: 0.8375
# Epoch 15/25
# 31/31 - 0s - loss: 0.5609 - accuracy: 0.8952 - val_loss: 1.1423 - val_accuracy: 0.8375
# Epoch 16/25
# 31/31 - 0s - loss: 0.7026 - accuracy: 0.8871 - val_loss: 1.1438 - val_accuracy: 0.8500
# Epoch 17/25
# 31/31 - 0s - loss: 0.6111 - accuracy: 0.8952 - val_loss: 1.2100 - val_accuracy: 0.8750
# Epoch 18/25
# 31/31 - 0s - loss: 0.5735 - accuracy: 0.9234 - val_loss: 1.3651 - val_accuracy: 0.8750
# Epoch 19/25
# 31/31 - 0s - loss: 0.5505 - accuracy: 0.9153 - val_loss: 1.8094 - val_accuracy: 0.8500
# Epoch 20/25
# 31/31 - 0s - loss: 0.8757 - accuracy: 0.8831 - val_loss: 1.2903 - val_accuracy: 0.8875
# Epoch 21/25
# 31/31 - 0s - loss: 0.7842 - accuracy: 0.8790 - val_loss: 1.4121 - val_accuracy: 0.8625
# Epoch 22/25
# 31/31 - 0s - loss: 0.8811 - accuracy: 0.8871 - val_loss: 1.5229 - val_accuracy: 0.8750
# Epoch 23/25
# 31/31 - 0s - loss: 0.8192 - accuracy: 0.8710 - val_loss: 1.3803 - val_accuracy: 0.8375
# Epoch 24/25
# 31/31 - 0s - loss: 0.9626 - accuracy: 0.8911 - val_loss: 1.4517 - val_accuracy: 0.8625
# Epoch 25/25
# 31/31 - 0s - loss: 1.1260 - accuracy: 0.8548 - val_loss: 1.2243 - val_accuracy: 0.8625

# %% [markdown]
# The first step to ***transfer learning*** is to
# * freeze all layers and
# * train only the top layers.
#
# For this step, ***a relatively large learning rate (1e-2)*** can be used.
#
# Note that validation accuracy and loss will usually be better than training accuracy and loss. This is because the regularization is strong, which only suppresses training-time metrics.
#
# Note that the convergence may take up to 10 epochs depending on choice of learning rate.
#
# If image augmentation layers were not applied, the validation accuracy may only reach ~60%.

# %%
model.summary()

# %% [markdown]
# The second step is to
# *  unfreeze a number of layers and
# * fit the model using smaller learning rate.
#
# In this example we show **unfreezing all layers**, but depending on specific dataset *it may be desireble to only unfreeze a fraction of all layers*.
#
# When the feature extraction with pretrained model works good enough, this step would give a very limited gain on validation accuracy.
# * In our case we only see a small improvement, as ImageNet pretraining already exposed the model to a good amount of our classes.
#
# On the other hand, ***when we use pretrained weights on a dataset that is more different from ImageNet***, this fine-tuning step can be ***crucial*** as the feature extractor also needs to be adjusted by a considerable amount.
# * Such a situation can be demonstrated if choosing CIFAR-100 dataset instead,
# * where fine-tuning boosts validation accuracy by about 10% to pass 80% on EfficientNetB0.
# * In such a case the convergence may take more than 50 epochs.
#
# A side note on freezing/unfreezing models:
# * setting trainable of a Model will simultaneously set all layers belonging to the `Model` to the same trainable attribute.
# * Each layer is trainable only if both the layer itself and the model containing it are trainable.
# * Hence when we need to partially freeze/unfreeze a model, we need to make sure the trainable attribute of the model is set to `True`.

# %%
def unfreeze_model(model):
    # We unfreeze the top 20 layers while leaving BatchNorm layers frozen
    for layer in model.layers[-20:]:
        if not isinstance(layer, layers.BatchNormalization):
            layer.trainable = True

    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )


unfreeze_model(model)

epochs = 15  # @param {type: "slider", min:8, max:50}
hist = model.fit(batch_train_dataset,
                 epochs=epochs,
                 validation_data = batch_test_dataset,
                 verbose=2)
plot_hist(hist)
# Out:
# Epoch 1/15
# 31/31 - 6s - loss: 0.4350 - accuracy: 0.9234 - val_loss: 0.7737 - val_accuracy: 0.9000
# Epoch 2/15
# 31/31 - 0s - loss: 0.4150 - accuracy: 0.9476 - val_loss: 0.9798 - val_accuracy: 0.8625
# Epoch 3/15
# 31/31 - 0s - loss: 0.2262 - accuracy: 0.9435 - val_loss: 1.1269 - val_accuracy: 0.8500
# Epoch 4/15
# 31/31 - 0s - loss: 0.4782 - accuracy: 0.9476 - val_loss: 1.1301 - val_accuracy: 0.8625
# Epoch 5/15
# 31/31 - 0s - loss: 0.2132 - accuracy: 0.9718 - val_loss: 1.0100 - val_accuracy: 0.8500
# Epoch 6/15
# 31/31 - 0s - loss: 0.5298 - accuracy: 0.9194 - val_loss: 0.8867 - val_accuracy: 0.8750
# Epoch 7/15
# 31/31 - 0s - loss: 0.3066 - accuracy: 0.9556 - val_loss: 0.9780 - val_accuracy: 0.8875
# Epoch 8/15
# 31/31 - 0s - loss: 0.3673 - accuracy: 0.9435 - val_loss: 0.8698 - val_accuracy: 0.8750
# Epoch 9/15
# 31/31 - 0s - loss: 0.2975 - accuracy: 0.9637 - val_loss: 0.9669 - val_accuracy: 0.8750
# Epoch 10/15
# 31/31 - 0s - loss: 0.3659 - accuracy: 0.9355 - val_loss: 0.9070 - val_accuracy: 0.8625
# Epoch 11/15
# 31/31 - 0s - loss: 0.3377 - accuracy: 0.9516 - val_loss: 1.0165 - val_accuracy: 0.8625
# Epoch 12/15
# 31/31 - 0s - loss: 0.2487 - accuracy: 0.9476 - val_loss: 0.9176 - val_accuracy: 0.8750
# Epoch 13/15
# 31/31 - 0s - loss: 0.4077 - accuracy: 0.9395 - val_loss: 1.0082 - val_accuracy: 0.8875
# Epoch 14/15
# 31/31 - 0s - loss: 0.2869 - accuracy: 0.9476 - val_loss: 1.0152 - val_accuracy: 0.8875
# Epoch 15/15
# 31/31 - 0s - loss: 0.2087 - accuracy: 0.9597 - val_loss: 1.0899 - val_accuracy: 0.9000

# %% [markdown]
# # Tips for fine tuning EfficientNet
#
# #### On unfreezing layers:
#
# * The [`BathcNormalization`](https://www.notion.so/mmmil/Batch-Normalization-e324bb0f38c34e60922b516d124555ed) layers need to be kept **frozen** ([more details](https://keras.io/guides/transfer_learning/)). <br />If they are also turned to trainable, the first epoch after unfreezing will significantly reduce accuracy.
# * In some cases it may be beneficial ***to open up only a portion of layers*** instead of unfreezing all. <br /> This will make fine tuning much faster when going to larger models like B7.
# * ***Each block needs to be all turned on or off***. <br />This is because the architecture includes a shortcut from the first layer to the last layer for each block. Not respecting blocks also significantly harms the final performance.
#
# #### Some other tips for utilizing `EfficientNet`:
#
# * Larger variants of EfficientNet do not guarantee improved performance, especially for tasks with less data or fewer classes. <br /> In such a case, the larger variant of EfficientNet chosen, the harder it is to tune hyperparameters.<br/> 많은 파라메터는 복잡한 모델을 의미하고, 이는 overfit을 피하기 위해 보다 많은 학습데이터가 필요함을 의미함.
# * EMA (Exponential Moving Average) is very helpful in training EfficientNet from scratch, but not so much for transfer learning. <br/>  learning curve를 스무스하게 보는 것이 from scratch에서 도움이 확실히 됨.
# * Do not use the `RMSprop` setup as in the original paper for transfer learning. <br />The momentum and learning rate are too high for transfer learning. It will easily corrupt the pretrained weight and blow up the loss. A quick check is to see if `loss` (as `categorical_cross_entropy`) is getting significantly larger than `log(NUM_CLASSES)` after the same epoch. If so, the initial learning rate/momentum is too high.
# * ***Smaller batch size benefit validation accuracy***, possibly due to effectively providing regularization.

# %% [markdown]
# # Grad-CAM class activation visualization
#
# https://keras.io/examples/vision/grad_cam/
#
# It is a **visualization technique** for CNN.
#
# ***Class Activation Map (CAM)*** is useful for understanding **which parts of a given image led a CNN(or convnet) to its final classification decision**.
#
# It consists of producing heatmaps of class activation over input images.
#
# A ***class activation heatmap*** is a **2D grid of scores** associated with a specific output class.
